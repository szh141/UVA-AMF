# %% [markdown]
# <a href="https://colab.research.google.com/github/szh141/UVA-AMF/blob/main/Imaris_ClearMap2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
img = np.zeros((5,5))
from matplotlib import pyplot as plt
img[0,0]=7
img[1,1]=1
plt.imshow(img)
plt.show()
img[img>1]=0
plt.imshow(img)
plt.show()

# %%
test2.dtype
# Out:
# dtype('int64')

# %%
test = np.arange(1024)
test2 = np.reshape(test,((32,32)))
plt.imshow(test2,cmap='gray')
plt.show()

test2[-1,-1] = 2E16-1
plt.imshow(test2,cmap='gray')
plt.show()

from skimage import io,data
test2 = test2.astype(np.int32)
io.imsave('test2.tif',test2)
# Out:
# <ipython-input-21-eff5b83d598a>:12: UserWarning: test2.tif is a low contrast image
#   io.imsave('test2.tif',test2)

# %% [markdown]
# download np.int32 file
# open in Fiji
# Edit>Option>Conversion uncheck scale
# change to 16bit
# the 2E16-1, goes to zero; the rest keeps the same
#
# so ABA_25um_annotation will remove all larger labels

# %% [markdown]
# https://forum.image.sc/t/low-intensity-32-bit-data-converted-to-high-16-bit-data/9784/2
#
#
#
# https://stackoverflow.com/questions/9696660/what-is-the-difference-between-int-int16-int32-and-int64
#
#
#
#   Type      Capacity
#
#    Int16 -- (-32,768 to +32,767)
#
#    Int32 -- (-2,147,483,648 to +2,147,483,647)
#
#    Int64 -- (-9,223,372,036,854,775,808 to +9,223,372,036,854,775,807)
#
#
#
# Float16 stores 4 decimal digits and the max is about 32,000. Float32 stores 8 decimal digits and the max is about 1038.
#
# So, the ABA_25um_annotation.tif must be int32
