# %% [markdown]
# <a href="https://colab.research.google.com/github/szh141/UVA-AMF/blob/main/NMJ_analysis_20260222.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install NMJ_analysis
# https://github.com/csudre/NMJ_Analyser

# %% [markdown]
# Claude
#
# in anaconda install following package with python 3.7
# * scipy 1.5.3
# * Pillow 7.2.0
# * numpy 1.19.1
# * pandas 1.1.0
# * nibabel 3.1.1
# In addition, the following modules are imported
# * glob
# * os
# * argparse
# * sys
# * Tinker Performs analysis of NMJ data

# %%
conda create -n nmj_analysis python=3.7

# %%
conda activate nmj_analysis

# %%
conda install scipy=1.5.3 pillow=7.2.0 numpy=1.19.1 pandas=1.1.0
# Out:
# <Image layer 'data' at 0x79051f4c9430>

# %%
# For nibabel (best installed via pip as conda may not have the exact version):
pip install nibabel==3.1.1

# %%
# Verify Installations
import scipy; print(scipy.__version__)        # 1.5.3
import PIL; print(PIL.__version__)             # 7.2.0
import numpy; print(numpy.__version__)         # 1.19.1
import pandas; print(pandas.__version__)       # 1.1.0
import nibabel; print(nibabel.__version__)     # 3.1.1

# %% [markdown]
# Built-in / Standard Library Modules: glob, os, arguparse, sys

# %%
conda install -c anaconda tk

# %%
# verify if tk works
# A small test window should appear if installed correctly.
python -m tkinter

# %% [markdown]
# Note: If you encounter dependency conflicts when installing exact versions together via conda, try installing them individually or use pip install with --no-deps for specific packages.

# %% [markdown]
# the github page didn't include all the dependencies.
# check out the paper's supplemntary information (but it didn't have version info)
# follow the windows install.
#
# if conda install, solving environment frozen.
# control + C to stop
# use pip install instead
#
# for example:
# conda install scipy=1.5.3
# instead using the following, doulbe = = sign
# use pip install scipy==1.5.3
#
#
# bash is shell, not python
# in bash like conda, type python to get into python
# >>>
# can use import skimage etc.
# after finish,
# quit() or exit() to get back to bash.
